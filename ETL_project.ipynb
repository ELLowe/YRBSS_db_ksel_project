# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
alcohol_file = "../Alcohol_and_Other_Drug_Use.csv"
alcohol_df = pd.read_csv(alcohol_file)

# %%
alcohol_df.head()
# Out:
#    YEAR LocationAbbr           LocationDesc DataSource  \
# 0  2005           MM  Miami-Dade County, FL      YRBSS
# 1  2017           SA          San Diego, CA      YRBSS
# 2  1995           HO            Houston, TX      YRBSS
# 3  2017           CK        Cherokee Nation      YRBSS
# 4  2013           WY                Wyoming      YRBSS
#
#                         Topic        Subtopic        ShortQuestionText  \
# 0  Alcohol and Other Drug Use  Other Drug Use  Illegal drugs at school
# 1  Alcohol and Other Drug Use     Alcohol Use   Current binge drinking
# 2  Alcohol and Other Drug Use  Other Drug Use         Ever cocaine use
# 3  Alcohol and Other Drug Use  Other Drug Use         Ever cocaine use
# 4  Alcohol and Other Drug Use     Alcohol Use      Current alcohol use
#
#                                Greater_Risk_Question  \
# 0  Were offered, sold, or given an illegal drug o...
# 1                    Reported current binge drinking
# ...

# %%
alcohol_df.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic',
#        'Subtopic', 'ShortQuestionText', 'Greater_Risk_Question', 'Description',
#        'Data_Value_Symbol', 'Data_Value_Type', 'Greater_Risk_Data_Value',
#        'Greater_Risk_Data_Value_Footnote_Symbol',
#        'Greater_Risk_Data_Value_Footnote', 'Greater_Risk_Low_Confidence_Limit',
#        'Greater_Risk_High_Confidence_Limit', 'Lesser_Risk_Question',
#        'Lesser_Risk_Data_Value', 'Lesser_Risk_Data_Value_Footnote_Symbol',
#        'Lesser_Risk_Data_Value_Footnote', 'Lesser_Risk_Low_Confidence_Limit',
#        'Lesser_Risk_High_Confidence_Limit', 'Sample_Size', 'Sex', 'Race',
#        'Grade', 'GeoLocation', 'TopicId', 'SubTopicID', 'QuestionCode',
#        'LocationId', 'StratID1', 'StratID2', 'StratID3', 'StratificationType'],
#       dtype='object')

# %%
cleaned_alcohol_df = alcohol_df[["YEAR","LocationDesc","Subtopic","Description","Greater_Risk_Question","Greater_Risk_Data_Value","Lesser_Risk_Question","Lesser_Risk_Data_Value","Sample_Size","Sex","Race","Grade","LocationId","GeoLocation","StratificationType"]]
cleaned_alcohol_df = cleaned_alcohol_df.dropna()
# cleaned_alcohol_df= cleaned_alcohol_df.reset_index(drop=True)
cleaned_alcohol_df=cleaned_alcohol_df.rename(columns={"YEAR":'surv_year',
                                                     "LocationDesc":'location_desc',
                                                     "Subtopic":'subtopic',
                                                     'Description':'description',
                                                     'Greater_Risk_Question':'greater_risk_question',
                                                     'Greater_Risk_Data_Value':'greater_risk_data_value',
                                                     'Lesser_Risk_Question':'lesser_risk_question',
                                                     'Lesser_Risk_Data_Value':'lesser_risk_data_value',
                                                     'Sample_Size':'sample_size',
                                                     'Sex':'sex',
                                                     'Race':'race',
                                                     'Grade':'grade',
                                                     'LocationId':'location_id',
                                                     'GeoLocation':'geolocation',
                                                     'StratificationType':'stratification_type'})
cleaned_alcohol_df.head()
# Out:
#     surv_year      location_desc        subtopic  \
# 2        1995        Houston, TX  Other Drug Use
# 8        1997        Houston, TX     Alcohol Use
# 13       1993             Nevada     Alcohol Use
# 15       2017       Pennsylvania  Other Drug Use
# 17       2007  San Francisco, CA  Other Drug Use
#
#                                           description  \
# 2   any form of cocaine, such as powder, crack, or...
# 8   at least one drink of alcohol, on at least 1 d...
# 13                              other than a few sips
# 15  any form of cocaine, such as powder, crack, or...
# 17  pills or shots, one or more times during their...
#
#                                 greater_risk_question  \
# 2                                   Ever used cocaine
# 8                             Currently drank alcohol
# 13  Had their first drink of alcohol before age 13...
# 15                                  Ever used cocaine
# 17  Ever took steroids without a doctor's prescrip...
#
# ...

# %%
tobacco_file= "../Tobacco_Use.csv"
tobacco_df=pd.read_csv(tobacco_file)

# %%
tobacco_df.head()
# Out:
#    YEAR LocationAbbr       LocationDesc DataSource        Topic  \
# 0  1997           WY            Wyoming      YRBSS  Tobacco Use
# 1  2011           CH        Chicago, IL      YRBSS  Tobacco Use
# 2  2007           WI          Wisconsin      YRBSS  Tobacco Use
# 3  2015           NE           Nebraska      YRBSS  Tobacco Use
# 4  2003           OL  Orange County, FL      YRBSS  Tobacco Use
#
#             Subtopic            ShortQuestionText  \
# 0      Cigarette Use           Ever cigarette use
# 1      Cigarette Use  Current daily cigarette use
# 2  Other Tobacco Use            Current cigar use
# 3      Cigarette Use  Current daily cigarette use
# 4      Cigarette Use           Ever cigarette use
#
#                Greater_Risk_Question  \
# 0       Ever tried cigarette smoking
# 1  Currently smoked cigarettes daily
# 2            Currently smoked cigars
# 3  Currently smoked cigarettes daily
# 4       Ever tried cigarette smoking
#
# ...

# %%
tobacco_df.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic',
#        'Subtopic', 'ShortQuestionText', 'Greater_Risk_Question', 'Description',
#        'Data_Value_Symbol', 'Data_Value_Type', 'Greater_Risk_Data_Value',
#        'Greater_Risk_Data_Value_Footnote_Symbol',
#        'Greater_Risk_Data_Value_Footnote', 'Greater_Risk_Low_Confidence_Limit',
#        'Greater_Risk_High_Confidence_Limit', 'Lesser_Risk_Question',
#        'Lesser_Risk_Data_Value', 'Lesser_Risk_Data_Value_Footnote_Symbol',
#        'Lesser_Risk_Data_Value_Footnote', 'Lesser_Risk_Low_Confidence_Limit',
#        'Lesser_Risk_High_Confidence_Limit', 'Sample_Size', 'Sex', 'Race',
#        'Grade', 'GeoLocation', 'TopicId', 'SubTopicID', 'QuestionCode',
#        'LocationId', 'StratID1', 'StratID2', 'StratID3', 'StratificationType'],
#       dtype='object')

# %%
cleaned_tobacco_df = tobacco_df[["YEAR","LocationDesc","Subtopic","Description","Greater_Risk_Question","Greater_Risk_Data_Value","Lesser_Risk_Question","Lesser_Risk_Data_Value","Sample_Size","Sex","Race","Grade","LocationId","GeoLocation","StratificationType"]]
cleaned_tobacco_df = cleaned_tobacco_df.dropna()
# cleaned_tobacco_df= cleaned_tobacco_df.reset_index(drop=True)
cleaned_tobacco_df=cleaned_tobacco_df.rename(columns={"YEAR":'surv_year',
                                                     "LocationDesc":'location_desc',
                                                     "Subtopic":'subtopic',
                                                     'Description':'description',
                                                     'Greater_Risk_Question':'greater_risk_question',
                                                     'Greater_Risk_Data_Value':'greater_risk_data_value',
                                                     'Lesser_Risk_Question':'lesser_risk_question',
                                                     'Lesser_Risk_Data_Value':'lesser_risk_data_value',
                                                     'Sample_Size':'sample_size',
                                                     'Sex':'sex',
                                                     'Race':'race',
                                                     'Grade':'grade',
                                                     'LocationId':'location_id',
                                                     'GeoLocation':'geolocation',
                                                     'StratificationType':'stratification_type'})
cleaned_tobacco_df.head()
# Out:
#     surv_year       location_desc           subtopic  \
# 1        2011         Chicago, IL      Cigarette Use
# 3        2015            Nebraska      Cigarette Use
# 4        2003   Orange County, FL      Cigarette Use
# 10       2005  Broward County, FL      Cigarette Use
# 11       2017   Orange County, FL  Other Tobacco Use
#
#                                           description  \
# 1   on all 30 days during the 30 days before the s...
# 3   on all 30 days during the 30 days before the s...
# 4                               even one or two puffs
# 10  on 20 or more days during the 30 days before t...
# 11  cigars, cigarillos, or little cigars, on at le...
#
#                      greater_risk_question  greater_risk_data_value  \
# 1        Currently smoked cigarettes daily                   2.3227
# 3        Currently smoked cigarettes daily                   5.2896
# 4             Ever tried cigarette smoking                  58.3984
# ...

# %%
Sexual_Behaviors_file= "../Sexual_Behaviors.csv"
Sexual_Behaviors_df=pd.read_csv(Sexual_Behaviors_file)

# %%
Sexual_Behaviors_df.head()
# Out:
#    YEAR LocationAbbr    LocationDesc DataSource             Topic  \
# 0  2013          MEM     Memphis, TN      YRBSS  Sexual Behaviors
# 1  1999           AS  American Samoa      YRBSS  Sexual Behaviors
# 2  1997           GU            Guam      YRBSS  Sexual Behaviors
# 3  2007           ME           Maine      YRBSS  Sexual Behaviors
# 4  2011           NJ      New Jersey      YRBSS  Sexual Behaviors
#
#            Subtopic      ShortQuestionText  \
# 0  Sexual Behaviors     IUD or implant use
# 1  Sexual Behaviors   No birth control use
# 2  Sexual Behaviors   No birth control use
# 3  Sexual Behaviors  Alcohol/drugs and sex
# 4       HIV Testing            HIV testing
#
#                                Greater_Risk_Question  \
# 0  Did not use an IUD (e.g., Mirena or ParaGard) ...
# 1  Did not use any method to prevent pregnancy du...
# 2  Did not use any method to prevent pregnancy du...
# 3  Drank alcohol or used drugs before last sexual...
# ...

# %%
cleaned_Sexual_Behaviors_df = Sexual_Behaviors_df[["YEAR","LocationDesc","Subtopic","Description","Greater_Risk_Question","Greater_Risk_Data_Value","Lesser_Risk_Question","Lesser_Risk_Data_Value","Sample_Size","Sex","Race","Grade","LocationId","GeoLocation","StratificationType"]]
cleaned_Sexual_Behaviors_df = cleaned_Sexual_Behaviors_df.dropna()
# cleaned_Sexual_Behaviors_df= cleaned_Sexual_Behaviors_df.reset_index(drop=True)
cleaned_Sexual_Behaviors_df=cleaned_Sexual_Behaviors_df.rename(columns={"YEAR":'surv_year',
                                                                       "LocationDesc":'location_desc',
                                                                         "Subtopic":'subtopic',
                                                                         'Description':'description',
                                                                         'Greater_Risk_Question':'greater_risk_question',
                                                                         'Greater_Risk_Data_Value':'greater_risk_data_value',
                                                                         'Lesser_Risk_Question':'lesser_risk_question',
                                                                         'Lesser_Risk_Data_Value':'lesser_risk_data_value',
                                                                         'Sample_Size':'sample_size',
                                                                         'Sex':'sex',
                                                                         'Race':'race',
                                                                         'Grade':'grade',
                                                                         'LocationId':'location_id',
                                                                         'GeoLocation':'geolocation',
                                                                         'StratificationType':'stratification_type'})
cleaned_Sexual_Behaviors_df.head()
# Out:
#     surv_year         location_desc          subtopic  \
# 4        2011            New Jersey       HIV Testing
# 5        1999         Massachusetts  Sexual Behaviors
# 8        2017  Borough of Bronx, NY       HIV Testing
# 16       2011           Memphis, TN  Sexual Behaviors
# 20       2015              Michigan  Sexual Behaviors
#
#                                           description  \
# 4       not counting tests done if they donated blood
# 5   among students who were currently sexually active
# 8       not counting tests done if they donated blood
# 16  had sexual intercourse with at least one perso...
# 20  to prevent pregnancy, among students who were ...
#
#                                 greater_risk_question  \
# 4   Were never tested for human immunodeficiency v...
# 5   Did not use a condom during last sexual interc...
# 8   Were never tested for human immunodeficiency v...
# 16                     Were currently sexually active
# ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/YRBSS"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['alcohol', 'tobacco', 'sexual_behaviors']

# %%
cleaned_alcohol_df.to_sql(name='alcohol', con=engine, if_exists='append', index=False)

# %%
cleaned_tobacco_df.to_sql(name='tobacco', con=engine, if_exists='append', index=False)

# %%
cleaned_Sexual_Behaviors_df.to_sql(name='sexual_behaviors', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from alcohol', con=engine).head()
# Out:
#    id  surv_year      location_desc        subtopic  \
# 0   1       1995        Houston, TX  Other Drug Use
# 1   2       1997        Houston, TX     Alcohol Use
# 2   3       1993             Nevada     Alcohol Use
# 3   4       2017       Pennsylvania  Other Drug Use
# 4   5       2007  San Francisco, CA  Other Drug Use
#
#                                          description  \
# 0  any form of cocaine, such as powder, crack, or...
# 1  at least one drink of alcohol, on at least 1 d...
# 2                              other than a few sips
# 3  any form of cocaine, such as powder, crack, or...
# 4  pills or shots, one or more times during their...
#
#                                greater_risk_question  greater_risk_data_value  \
# 0                                  Ever used cocaine                   4.9938
# 1                            Currently drank alcohol                  40.8283
# 2  Had their first drink of alcohol before age 13...                  39.9928
# ...

# %%
pd.read_sql_query('select * from tobacco', con=engine).head()
# Out:
#    id  surv_year       location_desc           subtopic  \
# 0   1       2011         Chicago, IL      Cigarette Use
# 1   2       2015            Nebraska      Cigarette Use
# 2   3       2003   Orange County, FL      Cigarette Use
# 3   4       2005  Broward County, FL      Cigarette Use
# 4   5       2017   Orange County, FL  Other Tobacco Use
#
#                                          description  \
# 0  on all 30 days during the 30 days before the s...
# 1  on all 30 days during the 30 days before the s...
# 2                              even one or two puffs
# 3  on 20 or more days during the 30 days before t...
# 4  cigars, cigarillos, or little cigars, on at le...
#
#                     greater_risk_question  greater_risk_data_value  \
# 0       Currently smoked cigarettes daily                   2.3227
# 1       Currently smoked cigarettes daily                   5.2896
# 2            Ever tried cigarette smoking                  58.3984
# ...

# %%
pd.read_sql_query('select * from sexual_behaviors', con=engine).head()
# Out:
#    id  surv_year         location_desc          subtopic  \
# 0   1       2011            New Jersey       HIV Testing
# 1   2       1999         Massachusetts  Sexual Behaviors
# 2   3       2017  Borough of Bronx, NY       HIV Testing
# 3   4       2011           Memphis, TN  Sexual Behaviors
# 4   5       2015              Michigan  Sexual Behaviors
#
#                                          description  \
# 0      not counting tests done if they donated blood
# 1  among students who were currently sexually active
# 2      not counting tests done if they donated blood
# 3  had sexual intercourse with at least one perso...
# 4  to prevent pregnancy, among students who were ...
#
#                                greater_risk_question  greater_risk_data_value  \
# 0  Were never tested for human immunodeficiency v...                  86.5079
# 1  Did not use a condom during last sexual interc...                  37.3616
# ...
